# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 해외 진출 선수 데이터 추출
script_dir = os.getcwd()  # 현재 작업 디렉토리
file_path = os.path.join(script_dir,'..','kwon','해외진출선수.csv')
file_path = os.path.abspath(file_path)

# CSV 파일을 읽기

player_list = pd.read_csv(file_path)

# data.info()
player_list.head()
# Out:
#    Unnamed: 0     구분   이름    출생      포지션  국내입단연도  첫구단활동종료  첫구단활동기간    첫소속구단  \
# 0           4  메이저리그  김광현  1988     좌완선발  2007.0   2019.0     13.0   SK와이번스
# 1           8  메이저리그  김현수  1988  좌익수/1루수  2006.0   2015.0     10.0    두산베어스
# 2           9  메이저리그  류현진  1987     좌완선발  2006.0   2012.0      7.0    한화이글스
# 3          10  메이저리그  박병호  1986      1루수  2005.0   2011.0      7.0    LG트윈스
# 4          12  메이저리그  양현종  1988     좌완투수  2007.0   2020.0     14.0  KIA타이거즈
#
#    해외진출연도     해외 첫 소속팀  국내복귀    복귀 소속팀  연봉(백만원)
# 0    2020  세인트루이스 카디널스  2022   SSG 랜더스   8100.0
# 1    2016    볼티모어 오리올스  2018    LG 트윈스   1400.0
# 2    2013        LA다저스  2024     한화이글스   2500.0
# 3    2016     미네소타 트윈스  2018    넥센히어로즈   1500.0
# 4    2021     텍사스 레이져스  2022  KIA 타이거즈   1000.0

# %%
new_df = player_list[['이름', '국내복귀', '복귀 소속팀']].copy()
new_df.columns = ['player', 'cbyear', 'cbteam']

# 결과 출력
print(new_df)
