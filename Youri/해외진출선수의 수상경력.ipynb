# %%
import pandas as pd
import numpy as np

# %%
total_player_list = pd.read_csv('../kwon/해외진출.csv', low_memory=False)
total_player_list.head()
# Out:
#    Unnamed: 0     구분   이름    출생        포지션  국내입단연도      국내 소속팀  해외진출연도  \
# 0           1  메이저리그  김하성  1995    내야 유틸리티  2014.0  넥센,키움 히어로즈  2021.0
# 1           2  메이저리그  배지환  1999  내,외야 유틸리티  2019.0      질롱 코리아  2022.0
# 2           3  메이저리그  이정후  1998    외야 유틸리티  2017.0  넥센,키움 히어로즈  2014.0
# 3           4  메이저리그  김광현  1988       좌완선발  2007.0      SK와이번스  2020.0
# 4           5  메이저리그  김동엽  1990   외야수/지명타자     NaN         NaN  2009.0
#
#       해외 첫 소속팀    국내복귀   복귀 소속팀
# 0   샌디에이고 파드리스     NaN      NaN
# 1    피츠버그 파이리츠     NaN      NaN
# 2  샌프란시스코 자이언츠     NaN      NaN
# 3  세인트루이스 카디널스  2022.0  SSG 랜더스
# 4       시카고 컵스  2016.0   삼성라이온즈

# %%
golden_glove = pd.read_csv('Golden Glove list.csv', low_memory=False)
golden_glove.head()
# Out:
#      연도       투수      포수     1루수     2루수     3루수     유격수  \
# 0  2023    페디 NC  양의지 두산  오스틴 LG  김혜성 키움  노시환 한화  오지환 LG
# 1  2022   안우진 키움  양의지 두산  박병호 KT  김혜성 키움  최정 SSG  오지환 LG
# 2  2021   미란다 두산  강민호 삼성  강백호 KT  정은원 한화  최정 SSG  김혜성 키움
# 3  2020  알칸타라 두산  양의지 NC  강백호 KT  박민우 NC  황재균 KT  김하성 키움
# 4  2019  린드블럼 두산  양의지 NC  박병호 키움  박민우 NC   최정 SK  김하성 키움
#
#                      외야수      지명타자
# 0   구자욱 삼성 박건우 NC 홍창기 LG    손아섭 NC
# 1  나성범 KIA 이정후 키움 피렐라 삼성    이대호 롯데
# 2   구자욱 삼성 이정후 키움 홍창기 LG    양의지 NC
# 3   김현수 LG 로하스 KT 이정후 키움   최형우 KIA
# 4    로하스 KT 샌즈 키움 이정후 키움  페르난데스 두산

# %%
cnt_golden_glove = pd.Series()

for column in golden_glove.columns[1:]:
    # 공백 앞의 첫 번째 단어 추출
    words = golden_glove[column].str.split(' ').str[0]
    # 단어를 count
    cnt_series = words.value_counts()
    
    # 기존 Series에 단어 count 추가
    cnt_golden_glove = cnt_golden_glove.add(cnt_series, fill_value=0)

# Series를 데이터프레임으로 변환
cnt_golden_glove = cnt_golden_glove.reset_index()
cnt_golden_glove.columns = ['Player', 'Count']

print(cnt_golden_glove)
# Out:
#     Player Count
# 0        -   2.0
# 1     가르시아   1.0
# 2      강기웅   3.0
# 3      강민호   6.0
# 4      강백호   2.0
# ..     ...   ...
# 146    홍성흔   6.0
# 147    홍세완   1.0
# 148    홍현우   3.0
# 149    황재균   1.0
# 150    황태환   1.0
#
# [151 rows x 2 columns]

# %%
# '이름' 열과 'Player' 열을 기준으로 'Count' 값을 매핑하여 'cnt_golden' 열을 추가
total_player_list['cnt_golden'] = total_player_list['이름'].map(cnt_golden_glove.set_index('Player')['Count'])

# 새로운 데이터프레임 생성
total_player_list_golden = total_player_list

# 결과 출력
print(total_player_list_golden)
# Out:
#     Unnamed: 0      구분   이름    출생       포지션  국내입단연도      국내 소속팀  해외진출연도  \
# 2            3   메이저리그  이정후  1998   외야 유틸리티  2017.0  넥센,키움 히어로즈  2014.0
# 3            4   메이저리그  김광현  1988      좌완선발  2007.0      SK와이번스  2020.0
# 4            5   메이저리그  김동엽  1990  외야수/지명타자     NaN         NaN  2009.0
# 5            6   메이저리그  김선기  1991      우완투수     NaN         NaN  2009.0
# 6            7   메이저리그  김재윤  1990        투수     NaN         NaN  2009.0
# 7            8   메이저리그  김현수  1988   좌익수/1루수  2006.0       두산베어스  2016.0
# 8            9   메이저리그  류현진  1987      좌완선발  2006.0      한화 이글스  2013.0
# 9           10   메이저리그  박병호  1986       1루수  2005.0       LG트윈스  2016.0
# 10          11   메이저리그  손호영  1994       내야수     NaN         NaN  2014.0
# 11          12   메이저리그  양현종  1988      좌완투수  2007.0     KIA타이거즈  2021.0
# 12          13   메이저리그  오승환  1982      우완투수  2005.0      삼성라이온즈  2016.0
# 13          14   메이저리그  윤정현  1993      좌완투수     NaN         NaN     NaN
# 14          15   메이저리그  이학수  1990       내야수     NaN         NaN  2008.0
# 15          16   메이저리그  장필준  1988      우완투수     NaN         NaN  2000.0
# 16          17   메이저리그  진우영  2001      우완투수     NaN         NaN     NaN
# 17          18   메이저리그  추신수  1982       NaN     NaN         NaN  2005.0
# 18          19   메이저리그  하재훈  1990       외야수     NaN         NaN  2008.0
# 19          20   메이저리그  황재균  1987       3루수  2006.0      현대유니콘스  2017.0
# 20          21   메이저리그  구대성  1969      좌완투수     NaN       한화이글스  2005.0
# 21          22   메이저리그  김병현  1979      우완투수     NaN         NaN  1999.0
# 22          23   메이저리그  김선우  1977      우완투수     NaN         NaN  2001.0
# 23          24   메이저리그  김성민  1993    내야수/포수     NaN         NaN  2011.0
# 24          25   메이저리그  류제국  1983      우완투수     NaN         NaN  2001.0
# 25          26   메이저리그  박찬호  1973        투수     NaN         NaN  1994.0
# 26          27   메이저리그  봉중근  1980      좌완투수     NaN         NaN  2002.0
# 27          28   메이저리그  서재응  1977      우완투수     NaN         NaN  2002.0
# 28          29   메이저리그  송승준  1980      우완투수     NaN         NaN  1999.0
# 29          30   메이저리그  윤석민  1986      우완투수  2005.0     KIA타이거즈  2014.0
# 30          31   메이저리그  이대은  1989      우완투수     NaN         NaN  2007.0
# 31          32   메이저리그  이대호  1982  1루수/지명타자  2001.0      롯데자이언츠  2016.0
# 32          33   메이저리그  이상훈  1971      좌완투수     NaN       LG트윈스  2000.0
# 33          34   메이저리그  임창용  1977    사이드암투수  1995.0      해태타이거즈  2013.0
# 34          35   메이저리그  최희섭  1979       NaN     NaN         NaN  2002.0
# 35          36  NPB 리그  김태균  1982       1루수  2001.0       한화이글스  2009.0
# 36          37  NPB 리그  이범호  1981       내야수  2000.0       한화이글스  2009.0
# 37          38  NPB 리그  이병규  1974       외야수  1997.0       LG트위스  2007.0
# 38          39  NPB 리그  이승엽  1976       1루수  1995.0      삼성라이온즈  2024.0
#
#           해외 첫 소속팀    국내복귀     복귀 소속팀 cnt_golden
# 2      샌프란시스코 자이언츠     NaN        NaN        NaN
# 3      세인트루이스 카디널스  2022.0    SSG 랜더스        1.0
# 4           시카고 컵스  2016.0     삼성라이온즈        NaN
# 5         시애틀 매리너스  2018.0     키움히어로즈        NaN
# 6     애리조나 다이아몬드백스  2015.0     삼성라이온즈        NaN
# 7        볼티모어 오리올스  2018.0     LG 트윈스        3.0
# 8            LA다저스  2024.0     한화 이글스        2.0
# 9         미네소타 트윈스  2018.0     넥센히어로즈        6.0
# 10          시카고 컵스  2019.0    롯데 자이언츠        NaN
# 11        텍사스 레이져스  2022.0   KIA 타이거즈        1.0
# 12     세인트루이스 카디널스  2019.0     삼성라이온즈        NaN
# 13             NaN     NaN     키움히어로즈        NaN
# 14          시카고 컵스  2019.0    롯데 자이언츠        NaN
# 15  LA에인절스 오브 애너하임  2015.0     삼성라이온즈        NaN
# 16             NaN  2024.0     LG 트윈스        NaN
# 17        시애틀 매리너스  2021.0    SSG 랜더스        NaN
# 18          시카고 컵스  2019.0    SSG 랜더스        NaN
# 19     샌프란시스코 자이언츠  2018.0      KT 위즈        1.0
# 20            뉴욕메츠     NaN        NaN        1.0
# 21   애리조나 다이아몬드 백스  2012.0     넥센히어로즈        NaN
# 22        보스턴 레드삭스  2008.0      두산베어즈        NaN
# 23      오클랜드 애슬레틱스  2019.0  (SK 와이번스)        NaN
# 24          시카고 컵스  2013.0     LG 트윈스        NaN
# 25          LA 다저스  2011.0     한화 이글스        NaN
# 26      애틀란타 브레이브스  2007.0     LG 트윈스        NaN
# 27            뉴욕메츠  2008.0   KIA 타이거즈        NaN
# 28        보스턴 레드삭스  2007.0    롯데 자이언츠        NaN
# 29         노포크 타이즈  2015.0    KIA타이거즈        1.0
# 30          시카고 컵스  2019.0       KT위즈        NaN
# 31        시애틀 매리너스  2017.0    롯데 자이언츠        7.0
# 32        보스턴 레드삭스  2001.0      LG트윈스        1.0
# 33          시카고 컵스  2014.0     삼성라이온즈        NaN
# 34          시카고 컵스  2007.0    KIA타이거즈        1.0
# 35       지바 롯데 마린즈  2012.0      한화이글스        3.0
# 36       소프트뱅크 호크스  2011.0    KIA타이거즈        2.0
# 37        주니치 드래곤즈  2010.0      LG트윈스        2.0
# 38       지바 롯데 마린스  2012.0     삼성라이온즈       10.0

# %%
# CSV 파일로 저장
total_player_list_golden.to_csv('total_player_list_golden.csv', index=False, encoding='utf-8-sig')
